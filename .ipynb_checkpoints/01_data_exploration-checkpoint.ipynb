# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\Moksh Buddhadev\Desktop\disaster_response_ai

# %%
import pandas as pd

# Load your CSV datasets
df1 = pd.read_csv("data/raw/crisis_dataset.csv")
df2 = pd.read_csv("data/raw/drone_disaster_area_identification_dataset.csv")
df3 = pd.read_csv("data/raw/natural_disasters_2024.csv")

print("✅ All CSV files loaded successfully!\n")

# Display first few rows of each dataset
print("Crisis Dataset:")
display(df1.head())

print("\nDrone Disaster Area Identification Dataset:")
display(df2.head())

print("\nNatural Disasters 2024 Dataset:")
display(df3.head())

# Basic info summary
print("\n--- Crisis Dataset Info ---")
df1.info()
# Out:
# ✅ All CSV files loaded successfully!
#
# Crisis Dataset:
#   post_id user_id            timestamp  platform  \
# 0  P00001   U9019  2024-08-21 15:36:00   Twitter
# 1  P00002   U3833  2024-08-17 14:20:00  Facebook
# 2  P00003   U7615  2024-08-19 17:33:00   Twitter
# 3  P00004   U1535  2024-08-16 04:12:00  Facebook
# 4  P00005   U1690  2024-08-21 04:15:00   Twitter
#
#                                  raw_text                   clean_text  \
# 0  Synthetic post text about earthquake 1  synthetic post earthquake 1
# 1  Synthetic post text about earthquake 2  synthetic post earthquake 2
# 2  Synthetic post text about earthquake 3  synthetic post earthquake 3
# 3  Synthetic post text about earthquake 4  synthetic post earthquake 4
# 4  Synthetic post text about earthquake 5  synthetic post earthquake 5
#
#   language sentiment_label emotion_category  sentiment_score  ...  latitude  \
# 0  Chinese         Neutral             hope             0.36  ...   34.1108
# 1  Chinese        Positive        gratitude             0.98  ...   34.4345
# 2  Chinese        Positive        gratitude            -0.96  ...   33.9961
# 3  Chinese        Positive          sadness             0.64  ...   29.8246
# 4  Chinese        Negative            anger            -0.73  ...   29.5657
#
#   longitude  region_sentiment likes shares comments_count engagement_index  \
# 0  100.1314             -0.51   178     56             31             0.74
# 1  102.6520             -0.93   421     31              2             0.86
# 2  102.2775             -0.19   291    179              9             0.92
# 3  102.2793             -0.23    62    183             16             0.11
# 4  100.3082             -0.45    26     60             40             0.79
#
#    aftershock_reports  official_announcements  gov_message_type
# 0                   0                       1       Information
# 1                   1                       0     Relief Update
# 2                   5                       0     Relief Update
# 3                   5                       0     Relief Update
# 4                   4                       0       Information
#
# [5 rows x 27 columns]
# Drone Disaster Area Identification Dataset:
#              timestamp  temperature  humidity  wind_speed  air_quality_index  \
# 0  2018-01-01 00:00:00    27.483571        70          30                200
# 1  2018-01-01 01:00:00    24.308678        70           5                100
# 2  2018-01-01 02:00:00    28.238443        70          20                200
# 3  2018-01-01 03:00:00    32.615149        60           0                150
# 4  2018-01-01 04:00:00    23.829233        40           0                150
#
#    water_level building_damage_level road_condition infrastructure_status  \
# 0            4              Moderate     Obstructed                Intact
# 1            0                 Minor        Blocked                Intact
# 2            2             Undamaged     Obstructed               Damaged
# 3            0             Undamaged     Obstructed               Damaged
# 4            1             Undamaged         Intact               Damaged
#
#    vegetation_cover  people_detected  heat_signatures  \
# 0               100                1                5
# 1               100                1                1
# 2                75                1                0
# 3               100                2                0
# 4                25                2                2
#
#    hazardous_material_detected disaster_severity_level affected_area_type  \
# 0                            1                  Medium            Flooded
# 1                            0                     Low            Flooded
# 2                            0                  Medium          Unblocked
# 3                            0                     Low            Flooded
# 4                            0                    High          Unblocked
#
#   immediate_action_required survivor_presence_likelihood
# 0                        No                         High
# 1                       Yes                          Low
# 2                        No                         High
# 3                        No                         High
# 4                        No                          Low
# Natural Disasters 2024 Dataset:
#    Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0            1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1            2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2            3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3            4         Flood      India   1.702505  2024-01-01 03:00:00
# 4            5         Flood     Brazil   7.917748  2024-01-01 04:00:00
#
#    Fatalities  Economic_Loss($)
# 0        9706      6.509790e+08
# 1        2233      5.538357e+08
# 2         478      6.910998e+07
# 3        2867      8.474880e+08
# 4         776      6.449297e+08
# --- Crisis Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   post_id                 5000 non-null   object
#  1   user_id                 5000 non-null   object
#  2   timestamp               5000 non-null   object
#  3   platform                5000 non-null   object
#  4   raw_text                5000 non-null   object
#  5   clean_text              5000 non-null   object
#  6   language                5000 non-null   object
#  7   sentiment_label         5000 non-null   object
#  8   emotion_category        5000 non-null   object
#  9   sentiment_score         5000 non-null   float64
#  10  confidence_score        5000 non-null   float64
#  11  shock_phase             5000 non-null   object
#  12  sentiment_trend_score   5000 non-null   float64
#  13  topic_id                5000 non-null   object
#  14  topic_keywords          5000 non-null   object
#  15  topic_category          5000 non-null   object
#  16  location_text           5000 non-null   object
#  17  latitude                5000 non-null   float64
#  18  longitude               5000 non-null   float64
#  19  region_sentiment        5000 non-null   float64
#  20  likes                   5000 non-null   int64
#  21  shares                  5000 non-null   int64
#  22  comments_count          5000 non-null   int64
#  23  engagement_index        5000 non-null   float64
#  24  aftershock_reports      5000 non-null   int64
#  25  official_announcements  5000 non-null   int64
#  26  gov_message_type        5000 non-null   object
# dtypes: float64(7), int64(5), object(15)
# memory usage: 1.0+ MB

# %%
import os
from pathlib import Path

raw_dir = Path("data/raw")
print("Files in data/raw:")
for f in raw_dir.iterdir():
    if f.is_file():
        print(f"- {f.name}   ({round(f.stat().st_size/1024,1)} KB)")
# Out:
# Files in data/raw:
# - crisis_dataset.csv   (1361.2 KB)
# - drone_disaster_area_identification_dataset.csv   (6548.4 KB)
# - natural_disasters_2024.csv   (794.8 KB)

# %%
import pandas as pd
from pathlib import Path


# If files are huge, change preview_rows to a small number
preview_rows = 5000

paths = {
    "crisis": "data/raw/crisis_dataset.csv",
    "drone": "data/raw/drone_disaster_area_identification_dataset.csv",
    "natural": "data/raw/natural_disasters_2024.csv",
}

# Load with a safe preview, then full load if small
dfs = {}
for key, p in paths.items():
    size_kb = Path(p).stat().st_size / 1024
    print(f"Loading {p} ({round(size_kb,1)} KB)...")
    if size_kb > 5_000:  # > ~5 MB, only preview
        print("  large file — reading first", preview_rows, "rows for preview")
        dfs[key] = pd.read_csv(p, nrows=preview_rows)
        dfs[key]._preview_only = True
    else:
        dfs[key] = pd.read_csv(p)
        dfs[key]._preview_only = False

# quick peek
for k, df in dfs.items():
    print(f"\n=== {k.upper()} (shape: {getattr(df,'shape',None)}) ===")
    display(df.head())
# Out:
# Loading data/raw/crisis_dataset.csv (1361.2 KB)...
# Loading data/raw/drone_disaster_area_identification_dataset.csv (6548.4 KB)...
#   large file — reading first 5000 rows for preview
# Loading data/raw/natural_disasters_2024.csv (794.8 KB)...
#
# === CRISIS (shape: (5000, 27)) ===
#   post_id user_id            timestamp  platform  \
# 0  P00001   U9019  2024-08-21 15:36:00   Twitter
# 1  P00002   U3833  2024-08-17 14:20:00  Facebook
# 2  P00003   U7615  2024-08-19 17:33:00   Twitter
# 3  P00004   U1535  2024-08-16 04:12:00  Facebook
# 4  P00005   U1690  2024-08-21 04:15:00   Twitter
#
#                                  raw_text                   clean_text  \
# 0  Synthetic post text about earthquake 1  synthetic post earthquake 1
# 1  Synthetic post text about earthquake 2  synthetic post earthquake 2
# 2  Synthetic post text about earthquake 3  synthetic post earthquake 3
# 3  Synthetic post text about earthquake 4  synthetic post earthquake 4
# 4  Synthetic post text about earthquake 5  synthetic post earthquake 5
#
#   language sentiment_label emotion_category  sentiment_score  ...  latitude  \
# 0  Chinese         Neutral             hope             0.36  ...   34.1108
# 1  Chinese        Positive        gratitude             0.98  ...   34.4345
# 2  Chinese        Positive        gratitude            -0.96  ...   33.9961
# 3  Chinese        Positive          sadness             0.64  ...   29.8246
# 4  Chinese        Negative            anger            -0.73  ...   29.5657
#
#   longitude  region_sentiment likes shares comments_count engagement_index  \
# 0  100.1314             -0.51   178     56             31             0.74
# 1  102.6520             -0.93   421     31              2             0.86
# 2  102.2775             -0.19   291    179              9             0.92
# 3  102.2793             -0.23    62    183             16             0.11
# 4  100.3082             -0.45    26     60             40             0.79
#
#    aftershock_reports  official_announcements  gov_message_type
# 0                   0                       1       Information
# 1                   1                       0     Relief Update
# 2                   5                       0     Relief Update
# 3                   5                       0     Relief Update
# 4                   4                       0       Information
#
# [5 rows x 27 columns]
# === DRONE (shape: (5000, 17)) ===
#              timestamp  temperature  humidity  wind_speed  air_quality_index  \
# 0  2018-01-01 00:00:00    27.483571        70          30                200
# 1  2018-01-01 01:00:00    24.308678        70           5                100
# 2  2018-01-01 02:00:00    28.238443        70          20                200
# 3  2018-01-01 03:00:00    32.615149        60           0                150
# 4  2018-01-01 04:00:00    23.829233        40           0                150
#
#    water_level building_damage_level road_condition infrastructure_status  \
# 0            4              Moderate     Obstructed                Intact
# 1            0                 Minor        Blocked                Intact
# 2            2             Undamaged     Obstructed               Damaged
# 3            0             Undamaged     Obstructed               Damaged
# 4            1             Undamaged         Intact               Damaged
#
#    vegetation_cover  people_detected  heat_signatures  \
# 0               100                1                5
# 1               100                1                1
# 2                75                1                0
# 3               100                2                0
# 4                25                2                2
#
#    hazardous_material_detected disaster_severity_level affected_area_type  \
# 0                            1                  Medium            Flooded
# 1                            0                     Low            Flooded
# 2                            0                  Medium          Unblocked
# 3                            0                     Low            Flooded
# 4                            0                    High          Unblocked
#
#   immediate_action_required survivor_presence_likelihood
# 0                        No                         High
# 1                       Yes                          Low
# 2                        No                         High
# 3                        No                         High
# 4                        No                          Low
# === NATURAL (shape: (10000, 7)) ===
#    Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0            1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1            2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2            3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3            4         Flood      India   1.702505  2024-01-01 03:00:00
# 4            5         Flood     Brazil   7.917748  2024-01-01 04:00:00
#
#    Fatalities  Economic_Loss($)
# 0        9706      6.509790e+08
# 1        2233      5.538357e+08
# 2         478      6.910998e+07
# 3        2867      8.474880e+08
# 4         776      6.449297e+08

# %%
for name, df in dfs.items():
    print(f"\n--- {name.upper()} ---")
    print("Shape:", df.shape)
    print("\nColumn dtypes:")
    print(df.dtypes)
    print("\nMissing values (count per column):")
    print(df.isna().sum().sort_values(ascending=False).head(20))
    print("\nTop 10 unique-value counts (categorical candidates):")
    for col in df.columns:
        if df[col].nunique() <= 20 and df[col].dtype == object:
            print(f"  {col}: {df[col].value_counts().to_dict()}")
# Out:
# --- CRISIS ---
# Shape: (5000, 27)
#
# Column dtypes:
# post_id                    object
# user_id                    object
# timestamp                  object
# platform                   object
# raw_text                   object
# clean_text                 object
# language                   object
# sentiment_label            object
# emotion_category           object
# sentiment_score           float64
# confidence_score          float64
# shock_phase                object
# sentiment_trend_score     float64
# topic_id                   object
# topic_keywords             object
# topic_category             object
# location_text              object
# latitude                  float64
# longitude                 float64
# region_sentiment          float64
# likes                       int64
# shares                      int64
# comments_count              int64
# engagement_index          float64
# aftershock_reports          int64
# official_announcements      int64
# gov_message_type           object
# dtype: object
#
# Missing values (count per column):
# post_id                  0
# user_id                  0
# timestamp                0
# platform                 0
# raw_text                 0
# clean_text               0
# language                 0
# sentiment_label          0
# emotion_category         0
# sentiment_score          0
# confidence_score         0
# shock_phase              0
# sentiment_trend_score    0
# topic_id                 0
# topic_keywords           0
# topic_category           0
# location_text            0
# latitude                 0
# longitude                0
# region_sentiment         0
# dtype: int64
#
# Top 10 unique-value counts (categorical candidates):
#   platform: {'Twitter': 1709, 'Weibo': 1661, 'Facebook': 1630}
#   language: {'Chinese': 5000}
#   sentiment_label: {'Positive': 1694, 'Negative': 1689, 'Neutral': 1617}
#   emotion_category: {'gratitude': 1032, 'hope': 1026, 'sadness': 1025, 'fear': 989, 'anger': 928}
#   shock_phase: {'Initial shock': 1681, 'Recovery': 1673, 'Ongoing rescue': 1646}
#   topic_id: {'T01': 1033, 'T04': 1022, 'T05': 1001, 'T03': 995, 'T02': 949}
#   topic_category: {'Rescue Efforts': 1035, 'Aftershocks': 1026, 'Donations': 987, 'Community Support': 981, 'Government Response': 971}
#   location_text: {'成都': 1291, '北京': 1281, '上海': 1214, '重庆': 1214}
#   gov_message_type: {'Information': 1306, 'Warning': 1243, 'Relief Update': 1231, 'Reassurance': 1220}
#
# --- DRONE ---
# Shape: (5000, 17)
#
# Column dtypes:
# timestamp                        object
# temperature                     float64
# humidity                          int64
# wind_speed                        int64
# air_quality_index                 int64
# water_level                       int64
# building_damage_level            object
# road_condition                   object
# infrastructure_status            object
# vegetation_cover                  int64
# people_detected                   int64
# heat_signatures                   int64
# hazardous_material_detected       int64
# disaster_severity_level          object
# affected_area_type               object
# immediate_action_required        object
# survivor_presence_likelihood     object
# dtype: object
#
# Missing values (count per column):
# timestamp                       0
# temperature                     0
# humidity                        0
# wind_speed                      0
# air_quality_index               0
# water_level                     0
# building_damage_level           0
# road_condition                  0
# infrastructure_status           0
# vegetation_cover                0
# people_detected                 0
# heat_signatures                 0
# hazardous_material_detected     0
# disaster_severity_level         0
# affected_area_type              0
# immediate_action_required       0
# survivor_presence_likelihood    0
# dtype: int64
#
# Top 10 unique-value counts (categorical candidates):
#   building_damage_level: {'Undamaged': 2495, 'Minor': 1009, 'Moderate': 734, 'Severe': 534, 'Destroyed': 228}
#   road_condition: {'Intact': 2522, 'Obstructed': 1248, 'Damaged': 762, 'Blocked': 468}
#   infrastructure_status: {'Intact': 3000, 'Damaged': 1517, 'Severely Damaged': 483}
#   disaster_severity_level: {'Low': 3018, 'Medium': 1508, 'High': 474}
#   affected_area_type: {'Flooded': 1498, 'Unblocked': 1473, 'Fire-Damaged': 1260, 'Collapsed Structure': 769}
#   immediate_action_required: {'No': 3015, 'Yes': 1985}
#   survivor_presence_likelihood: {'Low': 3463, 'High': 1537}
#
# --- NATURAL ---
# Shape: (10000, 7)
#
# Column dtypes:
# Disaster_ID           int64
# Disaster_Type        object
# Location             object
# Magnitude           float64
# Date                 object
# Fatalities            int64
# Economic_Loss($)    float64
# dtype: object
#
# Missing values (count per column):
# Disaster_ID         0
# Disaster_Type       0
# Location            0
# Magnitude           0
# Date                0
# Fatalities          0
# Economic_Loss($)    0
# dtype: int64
#
# Top 10 unique-value counts (categorical candidates):
#   Disaster_Type: {'Earthquake': 2036, 'Flood': 2018, 'Tornado': 2012, 'Wildfire': 1982, 'Hurricane': 1952}
#   Location: {'Brazil': 1743, 'India': 1677, 'Indonesia': 1649, 'Japan': 1648, 'USA': 1646, 'China': 1637}

# %%
import numpy as np

def try_parse_datetimes(df, sample=1000):
    parsed = []
    for col in df.columns:
        if df[col].dtype == object:
            sample_vals = df[col].dropna().astype(str).head(sample)
            if sample_vals.empty:
                continue
            # Heuristic: many values parse as dates
            parsed_count = 0
            for v in sample_vals:
                try:
                    pd.to_datetime(v)
                    parsed_count += 1
                except Exception:
                    pass
            if parsed_count / len(sample_vals) > 0.6:
                parsed.append(col)
    return parsed

for name, df in dfs.items():
    candidates = try_parse_datetimes(df)
    print(f"{name}: datetime candidates -> {candidates}")
    for c in candidates:
        try:
            dfs[name][c] = pd.to_datetime(dfs[name][c], errors="coerce")
            print(f"  parsed column {c} -> dtype {dfs[name][c].dtype}")
        except Exception as e:
            print("  failed to parse", c, e)
# Out:
# crisis: datetime candidates -> ['timestamp']
#   parsed column timestamp -> dtype datetime64[ns]
# drone: datetime candidates -> ['timestamp']
#   parsed column timestamp -> dtype datetime64[ns]
# natural: datetime candidates -> ['Date']
#   parsed column Date -> dtype datetime64[ns]

# %%
import matplotlib.pyplot as plt

for name, df in dfs.items():
    print(f"\n=== Numeric summary for {name} ===")
    num = df.select_dtypes(include=["number"])
    if num.shape[1] == 0:
        print("  (no numeric columns found)")
        continue
    display(num.describe().T)
    # quick histogram for each numeric column (small number)
    cols = num.columns.tolist()[:6]
    fig, axes = plt.subplots(len(cols), 1, figsize=(8, 2.5*len(cols)))
    if len(cols)==1:
        axes=[axes]
    for ax, col in zip(axes, cols):
        df[col].dropna().hist(bins=40, ax=ax)
        ax.set_title(f"{name} — {col}")
    plt.tight_layout()
    plt.show()
# Out:
# === Numeric summary for crisis ===
#                          count        mean         std       min        25%  \
# sentiment_score         5000.0    0.022140    0.573764   -1.0000   -0.47000
# confidence_score        5000.0    0.793014    0.112872    0.6000    0.70000
# sentiment_trend_score   5000.0   -0.009982    0.574721   -1.0000   -0.52000
# latitude                5000.0   31.507415    2.033227   28.0001   29.71950
# longitude               5000.0  105.026969    2.888831  100.0013  102.48285
# region_sentiment        5000.0   -0.005468    0.581025   -1.0000   -0.51000
# likes                   5000.0  249.133200  146.636770    0.0000  118.00000
# shares                  5000.0  100.394400   58.269322    0.0000   49.75000
# comments_count          5000.0   49.633800   29.074380    0.0000   25.00000
# engagement_index        5000.0    0.494246    0.289504    0.0000    0.24000
# aftershock_reports      5000.0    2.492000    1.704030    0.0000    1.00000
# official_announcements  5000.0    0.501600    0.500047    0.0000    0.00000
#
#                               50%         75%       max
# sentiment_score           0.04000    0.510000    1.0000
# confidence_score          0.79000    0.890000    0.9900
# sentiment_trend_score     0.00000    0.490000    1.0000
# latitude                 31.52770   33.299425   34.9994
# longitude               105.00095  107.560950  109.9991
# region_sentiment         -0.01000    0.500000    1.0000
# likes                   249.00000  379.000000  500.0000
# shares                  100.00000  152.000000  200.0000
# comments_count           50.00000   74.000000  100.0000
# engagement_index          0.49000    0.740000    1.0000
# aftershock_reports        2.00000    4.000000    5.0000
# official_announcements    1.00000    1.000000    1.0000
# === Numeric summary for drone ===
#                               count        mean         std   min        25%  \
# temperature                  5000.0   25.068839    4.869130  15.0  21.710475
# humidity                     5000.0   62.766000   15.008474  30.0  50.000000
# wind_speed                   5000.0   11.479000   12.097803   0.0   0.000000
# air_quality_index            5000.0  165.500000  119.493120  50.0  50.000000
# water_level                  5000.0    0.906800    1.161199   0.0   0.000000
# vegetation_cover             5000.0   59.605000   26.986379   0.0  50.000000
# people_detected              5000.0    1.978400    1.413766   0.0   1.000000
# heat_signatures              5000.0    1.023600    1.265450   0.0   0.000000
# hazardous_material_detected  5000.0    0.102000    0.302679   0.0   0.000000
#
#                                     50%         75%    max
# temperature                   25.067328   28.330053   40.0
# humidity                      70.000000   70.000000   90.0
# wind_speed                    10.000000   20.000000   50.0
# air_quality_index            150.000000  200.000000  500.0
# water_level                    1.000000    1.000000    5.0
# vegetation_cover              50.000000   75.000000  100.0
# people_detected                2.000000    3.000000    9.0
# heat_signatures                0.000000    2.000000    5.0
# hazardous_material_detected    0.000000    0.000000    1.0
# === Numeric summary for natural ===
#                     count          mean           std           min  \
# Disaster_ID       10000.0  5.000500e+03  2.886896e+03  1.000000e+00
# Magnitude         10000.0  5.559173e+00  2.619304e+00  1.000656e+00
# Fatalities        10000.0  4.984929e+03  2.900114e+03  0.000000e+00
# Economic_Loss($)  10000.0  5.049752e+08  2.861325e+08  1.036597e+06
#
#                            25%           50%           75%           max
# Disaster_ID       2.500750e+03  5.000500e+03  7.500250e+03  1.000000e+04
# Magnitude         3.263217e+00  5.589578e+00  7.829268e+00  9.999671e+00
# Fatalities        2.481750e+03  4.947000e+03  7.511250e+03  9.999000e+03
# Economic_Loss($)  2.636352e+08  5.078407e+08  7.527256e+08  9.998528e+08

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for name, df in dfs.items():
    plt.figure(figsize=(10, 4))
    sns.heatmap(df.isna(), cbar=False)
    plt.title(f"Missing value map — {name}")
    plt.xlabel("Columns")
    plt.ylabel("Rows (sampled)")
    plt.show()
